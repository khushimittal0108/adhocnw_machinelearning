# %% [markdown]
# <a href="https://colab.research.google.com/github/khushimittal0108/adhocnw_machinelearning/blob/SupervisedML/Comp_vis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '3.4.3'

# %%
#image name as first argumnet
data=sys.argv[1]

# %%
# image read
img=cv2.imread('cat.jpg',1)
img2=cv2.imread('cat.jpg',0)
#loading image in coloured format -- original image
img
# Out:
# array([[[ 35,  29,  30],
#         [ 34,  28,  29],
#         [ 34,  28,  29],
#         ...,
#         [147, 172, 188],
#         [154, 179, 195],
#         [162, 185, 200]],
#
#        [[ 33,  27,  28],
#         [ 33,  27,  28],
#         [ 33,  27,  28],
#         ...,
#         [147, 172, 188],
#         [153, 178, 194],
#         [162, 185, 200]],
#
#        [[ 30,  24,  25],
#         [ 30,  24,  25],
#         [ 30,  24,  25],
#         ...,
#         [147, 172, 188],
#         [153, 178, 194],
#         [162, 185, 200]],
#
#        ...,
#
#        [[220, 224, 248],
#         [220, 225, 246],
#         [220, 225, 246],
#         ...,
#         [212, 220, 243],
#         [212, 220, 243],
#         [212, 220, 243]],
#
#        [[218, 222, 246],
#         [218, 222, 246],
#         [219, 224, 245],
#         ...,
#         [212, 220, 243],
#         [212, 220, 243],
#         [212, 220, 243]],
#
#        [[215, 219, 244],
#         [215, 219, 243],
#         [217, 222, 243],
# ...

# %%
# shape 
img.shape
# Out:
# (189, 267, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61F39B0>

# %%
cv2_imshow(img-50)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61F34E0>

# %%
cv2_imshow(img+100)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61F3940>

# %%
cv2_imshow(img[0:200,60:500]+100)
# Out:
# <PIL.Image.Image image mode=RGB size=207x189 at 0x7FF2D61F3908>

# %%
cv2_imshow(img/2)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61F34E0>

# %%
cv2_imshow(img*2)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61F3940>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=267x189 at 0x7FF2D61F3C50>

# %%
img3=cv2.imread('flower.jpg',1)
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=225x224 at 0x7FF2D61FFDD8>

# %%
#to overwrite a file
cv2.imwrite('flower.jpg',img)
# Out:
# True

# %%
img3=cv2.imread('flower.jpg',1)

# %%
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=267x189 at 0x7FF2D61FFDD8>
