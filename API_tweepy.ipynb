# %% [markdown]
# <a href="https://colab.research.google.com/github/khushimittal0108/adhocnw_machinelearning/blob/SupervisedML/API_tweepy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy

# %%
consumerkey=''
consumersecret=''
accessToken=''
accessTokenSecret=''

auth=tweepy.OAuthHandler(consumer_key=consumerkey,consumer_secret=consumersecret)
auth.set_access_token(accessToken,accessTokenSecret)

# %%
api=tweepy.API(auth)

# %%
search=input("Enter word to be search:")
numberwords= int(input("number of words:"))
# Out:
# Enter word to be search:enrique
# number of words:10

# %%
result=api.search(search,count=numberwords)
result
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f241f6934a8>, _json={'created_at': 'Fri Jul 05 09:36:58 +0000 2019', 'id': 1147076895717986304, 'id_str': '1147076895717986304', 'text': 'RT @lizquenvibe: Enrique is such a sweet guy \U0001f97a❤️ https://t.co/Kqw9FWw1Bn', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'lizquenvibe', 'name': 'LizQuen', 'id': 876660168552923136, 'id_str': '876660168552923136', 'indices': [3, 15]}], 'urls': [], 'media': [{'id': 1146696528267902976, 'id_str': '1146696528267902976', 'indices': [49, 72], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1146696528267902976/pu/img/nPOJWq_wvwbkwgBc.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1146696528267902976/pu/img/nPOJWq_wvwbkwgBc.jpg', 'url': 'https://t.co/Kqw9FWw1Bn', 'display_url': 'pic.twitter.com/Kqw9FWw1Bn', 'expanded_url': 'https://twitter.com/lizquenvibe/status/1146696611981959168/video/1', 'type': 'photo', 'sizes': {'thumb': {'
# ...

# %%
for i in result:
  print(i.text)
# Out:
# RT @lizquenvibe: Enrique is such a sweet guy 🥺❤️ https://t.co/Kqw9FWw1Bn
# RT @lizquenvibe: Enrique is such a sweet guy 🥺❤️ https://t.co/Kqw9FWw1Bn
# RT @FCBarcelonaFl: 🎙 Enrique Cerezo (Atlético president) "I don't know if Griezmann signed a contract with Barcelona in March. If he did, t…
# My Name: Nwike Arah
# Siblings: Wekeco
# Dad: Nwike
# Foolish Cousins: Winks
# Unfortunate People: Wikipedia
# Friends: CNN
# P… https://t.co/nRCzvVd8xA
# RT @patrol_ph: Liza Soberano, hindi agad nakilala si Enrique Gil matapos sumailalim sa surgery https://t.co/DyR6qWFRri
# RT @lizquenvibe: Enrique is such a sweet guy 🥺❤️ https://t.co/Kqw9FWw1Bn
